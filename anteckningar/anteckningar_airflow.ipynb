# %% [markdown]
# * Från upstream till downstream
#     -  different data sources -> data lake -> data warehouse -> dashboard, ml model

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * från data sources
#     - extract data
# * unstrucured data, data lake
#     - transformerar datan
# * data warehouse
#     - structured data, ready for ML & dashboard

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Use cron scheduling to solve it?
# - ![image.png](attachment:image.png)

# %% [markdown]
# !["image.png"](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## DAGS: Directed Acylic graphs
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# * D: Varje task har 1 upstream eller 1 downstream
# * A: Tasks har ingen dependency till sig själv, inga looper
# * G: relationer mellan tasks moduleras av noder och verticies/edges

# %% [markdown]
# ![image.png](attachment:image.png)
